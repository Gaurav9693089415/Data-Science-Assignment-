# %%
import pandas as pd

# %%
df=pd.read_csv('Cardiotocographic.csv')
import numpy as np

# %%
## Handling with missing values
df.isnull().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
df.shape
# Out:
# (2126, 14)

# %%
df.size
# Out:
# 29764

# %%
df.columns
# Out:
# Index(['LB', 'AC', 'FM', 'UC', 'DL', 'DS', 'DP', 'ASTV', 'MSTV', 'ALTV',
#        'MLTV', 'Width', 'Tendency', 'NSP'],
#       dtype='object')

# %%
LB_mean=df['LB'].mean()
AC_mean=df['AC'].mean()
FM_mean=df['FM'].mean()
UC_mean=df['UC'].mean()
DL_mean=df['DL'].mean()
DS_mean=df['DS'].mean()
DP_mean=df['DP'].mean()
ASTV_mean=df['ASTV'].mean()
MSTV_mean=df['MSTV'].mean()
ALTV_mean=df['ALTV'].mean()
MLTV_mean=df['MLTV'].mean()
Width_mean=df['Width'].mean()
Tendency_mean=df['Tendency'].mean()
NSP_mean=df['NSP'].mean()
print(LB_mean,AC_mean,FM_mean,UC_mean,DL_mean,DS_mean,DP_mean,ASTV_mean,MSTV_mean,ALTV_mean,MLTV_mean,Width_mean,Tendency_mean,NSP_mean)
# Out:
# 133.3435983550352 0.0032189782438000465 0.009894484174097834 0.004390615424744109 0.0018953447635069313 2.5089835057102827e-06 0.00017515121174634704 46.99598415495999 1.3643783514792533 10.285964066432834 8.28488742706321 70.42926049411918 0.3163714038702473 1.304507175110962

# %%
df['LB'].fillna(LB_mean,inplace=True)
df['AC'].fillna(AC_mean,inplace=True)
df['DS'].fillna(DS_mean,inplace=True)
df['DP'].fillna(DP_mean,inplace=True)
df['MLTV'].fillna(MLTV_mean,inplace=True)
df['Width'].fillna(Width_mean,inplace=True)
df['Tendency'].fillna(Tendency_mean,inplace=True)
df['NSP'].fillna(NSP_mean,inplace=True)

# %%
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
df.isnull().sum()
# Out:
# LB          0
# AC          0
# FM          0
# UC          0
# DL          0
# DS          0
# DP          0
# ASTV        0
# MSTV        0
# ALTV        0
# MLTV        0
# Width       0
# Tendency    0
# NSP         0
# dtype: int64

# %%
## CHECKING INCONSISTENCIES IN DATA TYPES
df['LB'].unique()
# Out:
# array([120.        , 132.        , 133.        , 134.        ,
#        131.94823162, 122.        , 151.        , 150.        ,
#        131.        , 130.        , 129.        , 128.        ,
#        124.        , 115.        , 114.        , 116.        ,
#        158.        , 133.34359836, 156.        , 147.81657385,
#        149.        , 146.        , 148.        , 144.        ,
#        142.        , 136.        , 141.        , 138.        ,
#        140.        , 154.        , 145.        , 144.93508565,
#        139.        , 125.        , 123.        , 159.        ,
#        158.75766557,  52.        , 143.        , 148.96141613,
#        119.        , 118.9736874 , 121.        , 137.8325398 ,
#        123.78909453, 127.        , 128.84390776, 125.14358925,
#        124.62776778, 123.3350051 , 125.80994939, 126.        ,
#        118.        , 135.        , 144.34576434, 146.00059107,
#        137.        , 134.72723786, 133.28233138, 137.82451993,
# ...

# %%
df['AC'].unique()
# Out:
# array([0.        , 0.00637959, 0.00332226, ..., 0.00098039, 0.00067889,
#        0.00161551])

# %%
df.columns
# Out:
# Index(['LB', 'AC', 'FM', 'UC', 'DL', 'DS', 'DP', 'ASTV', 'MSTV', 'ALTV',
#        'MLTV', 'Width', 'Tendency', 'NSP'],
#       dtype='object')

# %%
df['FM'].unique()
# Out:
# array([ 0.00000000e+00,  7.23350250e-02,  2.22390318e-01,  4.07839867e-01,
#         3.80222841e-01,  4.41400304e-01,  3.82621951e-01,  4.50924609e-01,
#         4.69250211e-01,  3.40044743e-01,  4.25000000e-01,  3.35120664e-01,
#         1.35112594e-01,  9.87841950e-02,  1.07589658e-01,  1.11898017e-01,
#         8.86426590e-02,  1.02585488e-01,  8.49772380e-02,  1.09090909e-01,
#         7.92326940e-02,  6.49188510e-02,  5.46558700e-02,  5.75479570e-02,
#         4.70409710e-02,  3.79362670e-02,  1.15830120e-02,  1.79948590e-02,
#         2.01438850e-02,  4.68750000e-03,  3.34821400e-03,  6.00600600e-03,
#         8.34028000e-04,  2.50208500e-03, -2.30355800e-03, -1.77612400e-03,
#        -1.20186300e-03,  5.98205400e-03,  5.42005400e-03,  4.19287200e-03,
#         3.46706300e-03,  8.91265600e-03,  2.97619000e-03,  9.77198700e-03,
#         1.98807200e-03,  7.66871200e-03,  7.21153800e-03,  8.40336100e-03,
# ...

# %%
df['UC'].unique()
# Out:
# array([0.        , 0.00637959, 0.00830565, ..., 0.00697924, 0.00686274,
#        0.00610998])

# %%
df['DL'].unique()
# Out:
# array([ 0.00000000e+00,  3.18979300e-03,  3.32225900e-03,  2.56081900e-03,
#         9.44386100e-03,  8.41514700e-03,  8.34028000e-04,  9.83284000e-04,
#         2.53807100e-03,  1.51285900e-03,  5.00417000e-03,  4.17827300e-03,
#         4.56621000e-03,  4.57317100e-03,  4.26742500e-03,  4.21230000e-03,
#         2.23713600e-03,  3.12500000e-03,  3.04878000e-03,  9.06905521e-05,
#        -3.50000000e-05,  8.34028400e-03,  1.21580550e-02,  1.00083400e-02,
#         1.41643060e-02,  9.63698000e-03,  1.51745100e-03,  2.50208500e-03,
#         3.03951400e-03,  1.24843900e-03,  5.14138800e-03,  5.75539600e-03,
#         2.23214300e-03,  6.00600600e-03,  7.53012000e-03,  8.49858400e-03,
#        -5.90000000e-05,  1.66805700e-03,  9.03342000e-04,  2.27790400e-03,
#         3.02571900e-03,  1.31233600e-03,  8.30565000e-04,  3.22580600e-03,
#         4.17014200e-03,  8.29875500e-03,  1.82920600e-03,  4.83091800e-03,
# ...

# %%
df['DS'].unique()
# Out:
# array([ 0.00000000e+00, -1.79000000e-06,  3.66773608e-06,  2.50898351e-06,
#        -3.24000000e-06,  2.54296927e-06, -2.26000000e-06,  8.65602121e-07,
#         1.16544621e-06,  5.57785247e-07, -2.22000000e-06, -3.09000000e-06,
#        -2.52000000e-06, -3.27000000e-06,  6.32344823e-06, -1.09000000e-06,
#        -5.37000000e-06, -1.70000000e-06,  3.21484620e-06,  3.47927095e-06,
#        -4.21000000e-06,  1.04857389e-06,  2.70636000e-03, -8.96000000e-08,
#         1.39285783e-06, -3.98000000e-07, -4.76000000e-07,  3.55635347e-06,
#         4.07729571e-06,  3.72913403e-06, -2.61000000e-07,  6.18521847e-08,
#        -2.51000000e-06,  1.35429413e-08,  4.56585228e-06, -2.90000000e-06,
#        -2.50000000e-06, -2.05000000e-06, -1.35318000e-03,  4.22410892e-07,
#         3.26310012e-06,  1.94962916e-06, -5.05000000e-06,  3.00612027e-06,
#        -1.22000000e-07,  3.95240056e-07, -3.45000000e-07,  2.25957299e-06,
# ...

# %%
df['DP'].unique()
# Out:
# array([ 0.00000000e+00,  2.09863600e-03,  2.80504900e-03,  8.25540000e-04,
#         1.39275800e-03,  1.52439000e-03,  1.42247500e-03,  8.42460000e-04,
#         3.35570500e-03,  1.56250000e-03,  3.04878000e-03,  8.34028000e-04,
#        -1.35000000e-05,  1.75151212e-04,  1.41643100e-03,  4.42571502e-06,
#        -5.34759400e-03,  1.63398700e-03,  2.62470075e-06,  3.00312855e-05,
#         2.29112454e-07,  2.44883220e-06, -5.69000000e-06, -6.21000000e-06,
#         3.29589451e-05, -2.97000000e-05,  1.34541878e-05, -2.74000000e-06,
#        -2.19000000e-05, -2.56000000e-06,  1.24650370e-05,  1.06951880e-02,
#        -1.03000000e-05, -1.63000000e-05,  2.26458634e-06, -1.57000000e-05,
#        -2.25000000e-05,  2.95514208e-06,  8.06513438e-06, -3.43000000e-05,
#        -1.02000000e-06, -9.36000000e-06,  1.25177135e-05,  3.06810554e-06,
#        -2.04000000e-05, -1.88000000e-05,  2.77008300e-03,  2.32018600e-03,
# ...

# %%
df.columns
# Out:
# Index(['LB', 'AC', 'FM', 'UC', 'DL', 'DS', 'DP', 'ASTV', 'MSTV', 'ALTV',
#        'MLTV', 'Width', 'Tendency', 'NSP'],
#       dtype='object')

# %%
df['ASTV'].unique()
# Out:
# array([ 73.        ,  17.        ,  16.        ,  26.        ,
#         29.        ,  83.        ,  84.        ,  86.        ,
#         64.        ,  28.        ,  21.        ,  19.        ,
#         24.        ,  18.        ,  23.        ,  30.        ,
#         33.47914465,  80.        ,  87.        ,  26.48780945,
#         22.        ,  29.06769121,  27.        ,  40.        ,
#         20.        ,  43.        ,  34.        ,  61.        ,
#         70.        ,  57.        ,  58.        ,  39.        ,
#         41.        ,  33.        ,  25.        ,  44.        ,
#         46.        ,  45.        ,  52.        ,  53.        ,
#         56.        ,  65.        ,  36.        ,  35.        ,
#         38.        ,  62.        ,  51.        ,  67.        ,
#         68.        ,  72.        ,  63.        ,  60.        ,
#         38.14660236,  21.66834422,  47.        ,  50.        ,
#         27.25969234,  69.        ,  54.        ,  55.        ,
# ...

# %%
df['MSTV'].unique()
# Out:
# array([ 0.5       ,  2.1       ,  2.4       ,  5.9       ,  6.3       ,
#         0.3       ,  1.9       ,  2.        ,  1.4       ,  1.5       ,
#         2.3       ,  2.29339987,  1.7       ,  2.5       ,  0.30580103,
#         0.4       ,  0.2       ,  4.4       ,  6.        ,  4.5       ,
#         6.9       ,  2.9       ,  3.4       ,  3.2       ,  3.7       ,
#         3.6       ,  2.2       ,  1.6       ,  1.8       ,  4.7       ,
#         4.9       ,  5.        ,  7.        ,  1.3       ,  4.1       ,
#         5.4       ,  1.2       ,  0.8       ,  1.1       ,  0.9       ,
#         1.        ,  1.91453365,  1.7135425 ,  0.7       ,  2.8       ,
#         3.9       ,  5.2       ,  4.8       ,  4.3       ,  1.10518006,
#         0.6       ,  0.93063263,  1.18644979,  5.3       ,  2.6       ,
#         0.81526051,  1.11260106,  0.48851151,  3.3       ,  3.8       ,
#         0.91189313, 13.8       ,  0.25051665,  0.39785211,  0.39354822,
# ...

# %%
df['ALTV'].unique()
# Out:
# array([ 4.30000000e+01,  0.00000000e+00,  6.00000000e+00,  5.00000000e+00,
#         9.00000000e+00,  8.00000000e+00, -7.02935751e-01, -5.46430385e-01,
#         7.90000000e+01,  7.20000000e+01,  1.40000000e+01,  7.10000000e+01,
#         1.00000000e+00,  4.00000000e+01,  6.90000000e+01,  5.40000000e+01,
#         5.30000000e+01,  3.80000000e+01,  2.90000000e+01, -6.04108060e-02,
#         1.80000000e+01,  2.10000000e+01,  3.66400702e+01,  2.00000000e+01,
#         2.00000000e+00,  3.00000000e+00, -5.80259763e-01,  2.70000000e+01,
#         6.70000000e+01,  6.80000000e+01,  7.50000000e+01,  7.40000000e+01,
#         7.00000000e+00,  3.00000000e+01,  4.90000000e+01,  3.90000000e+01,
#        -3.34223433e-01, -4.46763869e-01,  5.32871502e-01,  3.01989385e+01,
#         3.20000000e+01,  1.90000000e+01,  1.60000000e+01,  6.49146292e+00,
#         1.82000000e+02,  3.40000000e+01,  3.10000000e+01,  5.80000000e+01,
# ...

# %%
df.columns
# Out:
# Index(['LB', 'AC', 'FM', 'UC', 'DL', 'DS', 'DP', 'ASTV', 'MSTV', 'ALTV',
#        'MLTV', 'Width', 'Tendency', 'NSP'],
#       dtype='object')

# %%
df['MLTV'].unique()
# Out:
# array([ 2.40000000e+00,  1.04000000e+01,  1.34000000e+01,  2.30000000e+01,
#         1.99000000e+01,  0.00000000e+00,  1.56000000e+01,  1.36000000e+01,
#         1.06000000e+01,  2.76000000e+01,  2.95000000e+01,  1.29000000e+01,
#         5.40000000e+00,  7.90000000e+00,  8.70000000e+00,  1.09000000e+01,
#         1.39000000e+01,  8.80000000e+00,  7.80000000e+00,  8.50000000e+00,
#         6.70000000e+00,  4.00000000e+00,  6.80000000e+00,  2.90000000e+00,
#         4.80000000e+00,  3.40000000e+00,  1.05000000e+01,  5.00000000e+00,
#         1.25000000e+01,  6.30000000e+00,  1.51000000e+01,  2.17000000e+01,
#         1.24000000e+01,  2.42000000e+01,  1.86903086e+01,  1.62000000e+01,
#         1.96000000e+01,  1.22000000e+01,  1.34341289e+01,  1.33000000e+01,
#         1.14000000e+01,  1.52000000e+01,  1.57000000e+01,  2.21000000e+01,
#         2.11000000e+01,  1.67255851e+01,  1.49000000e+01,  8.28488743e+00,
# ...

# %%
df['Width'].unique()
# Out:
# array([  64.        ,  130.        ,  117.        ,  150.        ,
#          69.92026114,   68.        ,   66.        ,   87.        ,
#         107.        ,  125.        ,   99.        ,  112.45111246,
#         128.        ,  141.        ,  145.        ,   16.        ,
#          12.        ,   24.        ,   10.        ,  143.        ,
#         149.        ,  144.        ,  126.        ,  134.        ,
#         138.        ,  129.        ,   98.        ,   93.        ,
#         142.        ,  148.        ,  120.        ,   70.42926049,
#          31.        , -174.        ,   18.        ,   20.        ,
#         100.        ,   44.37573548,   28.        ,   26.        ,
#         111.        ,   60.        ,   37.        ,   30.        ,
#         104.        ,  108.        ,   92.        ,  119.        ,
#         140.        ,  109.        ,  136.        ,  113.        ,
#          15.        ,   17.        ,   25.        ,   21.        ,
# ...

# %%
df['Tendency'].unique()
# Out:
# array([ 9.99926014e-01,  0.00000000e+00,  1.00000000e+00, -1.00000000e+00,
#         1.10922946e-02,  3.28970400e-03,  3.16371404e-01,  9.87842382e-01,
#         8.28090200e-03, -2.59343380e-02,  1.00607149e+00, -5.99107200e-03,
#        -1.00661422e+00, -6.47057600e-03,  1.22923532e-02, -1.21476810e-02,
#        -3.78846800e-03,  4.42943800e-03,  1.00312902e+00,  9.81337890e-01,
#         9.85729402e-01,  1.88044200e-03,  1.19756209e-02,  2.38459500e-03,
#        -3.00000000e+00,  2.13996940e-02,  9.71151191e-01, -1.00210848e+00,
#         1.00124823e+00,  6.55067600e-03, -9.94488285e-01,  9.71445618e-01,
#        -4.25352300e-03, -9.97403600e-03, -2.66400120e-02, -1.98864410e-02,
#        -1.89944450e-02, -1.48017800e-03,  8.13726100e-03, -3.07942200e-03,
#        -5.19414200e-03, -9.91883608e-01,  9.84422685e-01,  1.08158800e-02,
#         1.00184071e+00,  1.00308374e+00,  1.00793862e+00,  9.73593786e-01,
# ...

# %%
df['NSP'].unique()
# Out:
# array([ 2.        ,  1.        ,  3.        , -1.025988  ,  1.01084882,
#         0.99671416,  1.30450718,  3.00453507,  0.99775653,  5.        ,
#         1.01334917,  0.99792058,  1.00336665,  1.01749703,  1.01503495,
#         0.99796582,  1.00733543,  0.98342028,  2.00660501,  2.01817732,
#         2.00412825, -1.        ,  0.99418412,  1.01828761,  1.99573874,
#         1.0107802 ,  1.99416358,  1.00377816,  0.97544038,  0.99223419,
#         0.99768784,  1.96492092,  0.98122639,  0.99120013,  0.98483388,
#         2.97130924,  0.99284679,  1.00350971,  0.99597399,  3.0191516 ,
#         3.01518503,  1.99747195,  0.97973798,  2.01631524,  2.03516005,
#         1.99860173,  0.99167495,  0.98839285,  1.00817061,  0.98749813,
#         0.99379572,  0.98900567,  0.99634758,  1.0003288 ,  1.01821721,
#         1.02128352,  0.99106613,  1.01663825,  1.00206333,  0.98145959,
#         1.00068221,  1.00026942,  1.00615323,  0.9959162 ,  1.0198268 ,
# ...

# %% [raw]
# ## CONCLUSION: Here,There is no inconsistency in data types

# %% [markdown]
# ## Detecting outliers

# %%
col_nam=list(df.columns)
col_nam
# Out:
# ['LB',
#  'AC',
#  'FM',
#  'UC',
#  'DL',
#  'DS',
#  'DP',
#  'ASTV',
#  'MSTV',
#  'ALTV',
#  'MLTV',
#  'Width',
#  'Tendency',
#  'NSP']

# %%
import matplotlib.pyplot as plt

# %%
## visualisatoion of outliers by boxplot
fig=plt.figure(figsize=(20,10))
for i in col_nam:
    df.boxplot(column=col_nam)
    plt.show()

# %%
## finding outliers manually
Q1=df.quantile(.25)
Q2=df.quantile(.50)
Q3=df.quantile(.75)
IQR=Q3-Q1
print('IQR  for each column:',IQR)
# Out:
# IQR  for each column: LB          14.000000
# AC           0.005606
# FM           0.002567
# UC           0.004685
# DL           0.003289
# DS           0.000000
# DP           0.000000
# ASTV        29.000000
# MSTV         1.000000
# ALTV        11.000000
# MLTV         6.200000
# Width       63.000000
# Tendency     1.000000
# NSP          0.000000
# dtype: float64

# %%
upper_quant=Q3+1.5*IQR
print('upper_quantile:',upper_quant)
low_quant=Q1-1.5*IQR
print('lower quantile:',low_quant)
# Out:
# upper_quantile: LB          161.000000
# AC            0.014015
# FM            0.006416
# UC            0.013564
# DL            0.008224
# DS            0.000000
# DP            0.000000
# ASTV        104.500000
# MSTV          3.200000
# ALTV         27.500000
# MLTV         20.100000
# Width       194.500000
# Tendency      2.500000
# NSP           1.000000
# dtype: float64
# lower quantile: LB          105.000000
# AC           -0.008409
# FM           -0.003850
# UC           -0.005177
# DL           -0.004934
# DS            0.000000
# DP            0.000000
# ASTV        -11.500000
# MSTV         -0.800000
# ALTV        -16.500000
# MLTV         -4.700000
# Width       -57.500000
# Tendency     -1.500000
# NSP           1.000000
# dtype: float64

# %% [raw]
# # using lower and upper quantile we can find outliers for each column seperately

# %%
## outlier for AC column
df_AC_outlier=df[(df['AC']<-0.008409)|(df['AC']>0.014015)]
df_AC_outlier
# Out:
#               LB        AC        FM        UC        DL        DS        DP  \
# 8     122.000000  0.038567  0.000000  0.001517  0.000000  0.000000  0.000000
# 23    128.000000 -0.019284  0.000000  0.000000  0.000000  0.000000  0.000000
# 83    145.000000  0.014706  0.008403  0.002101  0.000000  0.000000  0.000000
# 85    145.000000  0.014230  0.025873  0.001294  0.000000  0.000000  0.000000
# 116   133.343598  0.038567  0.000000  0.006993  0.002331  0.000003  0.000175
# 157   123.000000 -0.019284  0.000000  0.006400  0.000000  0.000000  0.000000
# 181   138.000000  0.017241  0.000000  0.005305  0.000000  0.000000  0.000000
# 496   130.000000  0.014178  0.091743  0.000938  0.000000  0.000000  0.000000
# 497   130.000000  0.015552  0.083981  0.001555 -0.000026  0.000000  0.000000
# 498   130.000000  0.015258  0.115023  0.000000  0.000000  0.000000  0.000000
# 500   131.000000  0.014178  0.015013  0.000834  0.000000  0.000000  0.000000
# ...

# %%
df.boxplot(column='AC')
plt.show()

# %%
## removing outliers
df_no_AC_outlier=df[(df['AC']>=-0.008409)&(df['AC']<=0.014015)]
df_no_AC_outlier
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
df1=df_no_AC_outlier
df1
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %% [raw]
# ## similarly we can find outliers for others column

# %% [markdown]
# ## statical summary

# %%
df1.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2083.000000  2083.000000  2083.000000  2083.000000  2083.000000
# mean    133.343325     0.002966     0.009739     0.004412     0.001922
# std      11.276603     0.003526     0.068079     0.003354     0.003367
# min      51.842487    -0.000185    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001881     0.000000
# 50%     133.000000     0.001587     0.000000     0.004518     0.000000
# 75%     140.000000     0.005193     0.002509     0.006573     0.003336
# max     214.000000     0.013861     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2083.000000  2083.000000  2083.000000  2083.000000  2083.000000
# mean      0.000003     0.000177    47.142655     1.346947    10.452257
# std       0.000142     0.000841    18.859283     1.139799    21.331062
# ...

# %% [markdown]
# ## Data visualisation

# %%
fig=plt.figure(figsize=(20,10))
df1.hist();
plt.show()

# %%
## Histogram for DL column,similary we can find for others column also
df['DL'].hist()
plt.show()

# %%
## corelation and corelation heatmap
df1_corr=df1.corr()
df1_corr
# Out:
#                 LB        AC        FM        UC        DL        DS  \
# LB        1.000000 -0.076311  0.017360 -0.166558 -0.127591 -0.005469
# AC       -0.076311  1.000000  0.003902  0.106241 -0.092325 -0.040191
# FM        0.017360  0.003902  1.000000 -0.049739  0.011011  0.030008
# UC       -0.166558  0.106241 -0.049739  1.000000  0.188264 -0.007084
# DL       -0.127591 -0.092325  0.011011  0.188264  1.000000  0.058464
# DS       -0.005469 -0.040191  0.030008 -0.007084  0.058464  1.000000
# DP       -0.048230 -0.078539  0.122739  0.071615  0.143463  0.004256
# ASTV      0.242549 -0.260317 -0.030455 -0.185284 -0.073407  0.008345
# MSTV     -0.179812  0.116233  0.016238  0.200566  0.433620  0.016984
# ALTV      0.213728 -0.322395 -0.010583 -0.233547 -0.191033 -0.004553
# MLTV     -0.002714 -0.086229 -0.005239 -0.052165 -0.171217  0.034533
# Width    -0.124498  0.260074  0.094492  0.120267  0.422536  0.041960
# Tendency  0.233846  0.009434 -0.022981 -0.061009 -0.020569 -0.015426
# ...

# %%
##plt.figure(figsize=(10,11))
sns.heatmap(df_corr,annot=True,cmap='coolwarm',fmt='2f')
plt.title("Correlation Heatmap")
plt.show()

# %%
import seaborn as sns

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df1_corr,annot=True,cmap='coolwarm')
plt.title('Correlation Heatmap',size=30,y=(1.1),color='red')
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
## pairplot
sns.pairplot(data=df1,height=2)
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
